# %% [markdown]
# # Lab 21 — Fine-tuning LLMs · RUN ALL (T4)
#
# Chay tu tren xuong. Runtime > Change runtime type > **T4 GPU** truoc khi bat dau.
#
# | O | Lam gi | Thoi gian |
# |---|---|---|
# | 1 | clone + install | ~1 phut |
# | 2 | smoke: import + unit test | ~30 giay |
# | 3 | **core pipeline NB1 -> NB5** | ~80 phut |
# | 4 | gatekeeper + in ket qua | ~10 giay |

# %%
# @title 1. Setup — clone + install (chạy ô này trước)
import os, subprocess, sys

REPO = "https://github.com/hieutrungdao/Day21-Track3-Finetuning-Lab.git"
if not os.path.exists("Day21-Track3-Finetuning-Lab"):
    subprocess.run(["git", "clone", "-q", REPO], check=True)
os.chdir("/content/Day21-Track3-Finetuning-Lab")
subprocess.run(["git", "pull", "-q"], check=False)
sys.path.insert(0, "src")

# Install from requirements.txt, NOT a copied list. The copied list is how the
# torchao>=0.16 pin reached requirements.txt and this bootstrap on different days --
# and a bootstrap missing a pin does not fail here, it fails 10 minutes later inside
# get_peft_model(). One source of truth. torch is preinstalled on Colab and
# requirements.txt pins it compatibly, so that line is a no-op.
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"],
               check=True)

import torch
print("commit :", subprocess.run(["git","rev-parse","--short","HEAD"],
                                 capture_output=True, text=True).stdout.strip())
print("GPU    :", torch.cuda.get_device_name(0) if torch.cuda.is_available()
      else "NONE — Runtime > Change runtime type > T4 GPU")
if torch.cuda.is_available():
    print("VRAM   : %.1f GB" % (torch.cuda.get_device_properties(0).total_memory/1024**3))
# Out:
# commit : 4f619a4
# GPU    : Tesla T4
# VRAM   : 14.6 GB

# %%
# @title 2. Smoke — imports, seed data, unit tests (no GPU needed)
# !python scripts/verify.py --smoke
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 2.18s
#
# 6 passed · 0 warnings · 1 failures
#
# Not ready to submit — fix the FAILs above.

# %%
# @title 3. Core pipeline — NB1 → NB5
# EVAL_LIMIT truncates both eval sets: "" = full run (submittable),
# 8 = ~fast smoke pass. STAGES lets you resume after a failure.
import os
import sys # Thêm dòng này để truy cập sys.path
COMPUTE_TIER = "T4"        # @param ["CPU","LAPTOP","T4","BIGGPU"]
EVAL_LIMIT   = "8"         # @param ["", "4", "8", "16", "25"]
STAGES       = "nb1 nb2 nb3 nb4 nb5"   # @param {type:"string"}

os.environ["COMPUTE_TIER"] = COMPUTE_TIER
if EVAL_LIMIT:
    os.environ["EVAL_LIMIT"] = EVAL_LIMIT
else:
    os.environ.pop("EVAL_LIMIT", None)

# Đảm bảo thư mục 'src' nằm trong sys.path để tìm thấy các mô-đun cục bộ như 'labkit'.
# Điều này hữu ích nếu môi trường bị reset hoặc ô thiết lập trước đó chưa hoàn chỉnh.
if os.path.isdir("src") and os.path.abspath("src") not in sys.path:
    sys.path.insert(0, os.path.abspath("src"))

from labkit import device
print(device.banner(), "\n")

# !python scripts/colab_run.py {STAGES}
# Out:
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
#
# tier=T4  mask=assistant-only  eval_limit=8
#
# ========================================================================
# NB1 — data, chat template & loss mask
# ========================================================================
# tier=T4  model=unsloth/Qwen3.5-4B  max_length=1024
# 250 mẫu huấn luyện
# {
#   "instruction": "Phân loại ticket chăm sóc khách hàng sau thành JSON với đúng 4 khóa: intent, urgency, product, sentiment. Chỉ trả về JSON, không giải thích.\n\nintent thuộc: doi_tra | van_chuyen | hoan_tien | san_pham_loi | hoi_thong_tin\nurgency thuộc: cao | trung_binh | thap\nsentiment thuộc: tieu_cuc | trung_tinh | tich_cuc\nproduct: tên sản phẩm xuất hiện trong ticket.",
#   "input": "Alo sh
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 2.76k/2.76k [00:00<00:00, 6.33MB/s]
# tokenizer_config.json: 100% 15.7k/15.7k [00:00<00:00, 52.4MB/s]
# vocab.json: 100% 5.23M/5.23M [00:00<00:00, 92.0MB/s]
# merges.txt: 100% 3.35M/3.35M [00:00<00:00, 130MB/s]
#
# tokenizer.json: downloading bytes:  28% 5.67M/20.0M [00:00<00:01, 9.77MB/s]
# tokenizer.json: downloading bytes: 100% 6.23M/6.23M [00:00<00:00, 10.3MB/s,  616kB/s  ]
# tokenizer.json: reconstructing file: 100% 20.0M/20.0M [00:00<00:00, 33.1MB/s, 1.98MB/s  ]
# added_tokens.json: 100% 904/904 [00:00<00:00, 6.14MB/s]
# special_tokens_map.json: 100% 876/876 [00:00<00:00, 6.19MB/s]
# chat_template.jinja: 100% 7.99k/7.99k [00:00<00:00, 32.1MB/s]
# eos_token: <|im_end|>
# VERDICT: reasoning preserved — safe to train on traces
#
# --- chuỗi đã render ---
# <|im_start|>user
# 2+2?<|im_end|>
# <|im_start|>assistant
# <think>
# buoc 1: kiem tra. buoc 2: tra loi.
# </think>
#
# 4<|im_end|>
#
# ======================================================================
# mode = assistant-only   supervised 39/94 (41%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# ======================================================================
# mode = everything   supervised 94/94 (100%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# <|im_start|>system
# Phân loại ticket sau.<|im_end|>
# <|im_start|>user
# Alo shop, mình đặt balo laptop mã đơn VN411453. Cho tôi trả lại. Đã 3 ngày rồi. Cho tôi hỏi.<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# {
#   "mask_mode": "assistant-only",
#   "n_supervised": 39,
#   "n_total": 94,
#   "supervised_fraction": 0.4149,
#   "answer_is_supervised": true,
#   "question_is_masked": true
# }
# {
#   "n": 250,
#   "mean": 93.1,
#   "p50": 93,
#   "p95": 98,
#   "p99": 100,
#   "max": 101,
#   "suggested_max_length": 256
# }
#
# ⚠ p95 gợi ý max_length=256 nhưng tier đang đặt 1024. Ghi lại lựa chọn của bạn trong REPORT.md.
# train=225  val=25  -> /content/Day21-Track3-Finetuning-Lab/data/split
#
# -- NB1 ok in 19s
#
# ========================================================================
# NB2 — freeze eval + three baselines
# ========================================================================
# ⚠ EVAL_LIMIT=8 — SMOKE MODE, not a submittable run
# target=8  regression=8  tier=T4
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# model.safetensors.index.json: 100% 76.2k/76.2k [00:00<00:00, 167MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/5.33G [00:00<?, ?B/s]
# Downloading bytes:   0% 7.30M/9.32G [00:00<14:55, 10.4MB/s]
# Downloading bytes:   2% 176M/9.32G [00:01<00:36, 253MB/s,  207MB/s  ]
# Downloading bytes:   3% 244M/9.32G [00:01<00:31, 284MB/s,  253MB/s  ]
# Downloading bytes:   3% 289M/9.32G [00:01<00:42, 215MB/s,  284MB/s  ]
# Downloading bytes:   3% 323M/9.32G [00:01<00:44, 200MB/s,  215MB/s  ]
# Downloading bytes:   5% 442M/9.32G [00:02<00:34, 256MB/s,  238MB/s  ]
# Downloading bytes:   7% 608M/9.32G [00:03<00:39, 220MB/s,  241MB/s  ]
# Downloading bytes:   7% 665M/9.32G [00:03<00:47, 182MB/s,  171MB/s  ]
# Downloading bytes:   9% 852M/9.32G [00:04<00:45, 187MB/s,  219MB/s  ]
# Downloading bytes:   9% 885M/9.32G [00:04<00:47, 178MB/s,  187MB/s  ]
# Downloading bytes:  12% 1.14G/9.32G [00:05<00:40, 202MB/s,  210MB/s  ]
# Downloading bytes:  14% 1.32G/9.32G [00:07<00:55, 144MB/s,  178MB/s  ]
# Downloading bytes:  15% 1.42G/9.32G [00:07<00:47, 166MB/s,  147MB/s  ]
# Downloading bytes:  23% 2.18G/9.32G [00:10<00:25, 283MB/s,  286MB/s  ]
# Downloading bytes:  29% 2.73G/9.32G [00:13<00:41, 159MB/s,  227MB/s  ]
# Downloading bytes:  30% 2.76G/9.32G [00:13<00:52, 125MB/s,  159MB/s  ]
# Downloading bytes:  30% 2.80G/9.32G [00:13<00:47, 137MB/s,  125MB/s  ]
# Downloading bytes:  38% 3.52G/9.32G [00:17<00:38, 150MB/s,  146MB/s  ]
# Downloading bytes:  39% 3.64G/9.32G [00:18<00:35, 158MB/s,  143MB/s  ]
# Downloading bytes:  44% 4.09G/9.32G [00:21<00:38, 137MB/s,  155MB/s  ]
# Downloading bytes:  45% 4.17G/9.32G [00:22<00:52, 98.7MB/s,  113MB/s  ]
# Downloading bytes:  51% 4.76G/9.32G [00:24<00:19, 239MB/s,  231MB/s  ]
# Downloading bytes:  52% 4.86G/9.32G [00:25<00:24, 179MB/s,  181MB/s  ]
# Downloading bytes:  54% 4.99G/9.32G [00:26<00:34, 126MB/s,  150MB/s  ]
# Downloading bytes:  60% 5.59G/9.32G [00:29<00:15, 246MB/s,  284MB/s  ]
# Downloading bytes:  61% 5.70G/9.32G [00:30<00:22, 164MB/s,  159MB/s  ]
# Downloading bytes:  62% 5.81G/9.32G [00:30<00:24, 145MB/s,  135MB/s  ]
# Downloading bytes:  69% 6.44G/9.32G [00:33<00:11, 261MB/s,  326MB/s  ]
# Downloading bytes:  73% 6.77G/9.32G [00:36<00:19, 132MB/s,  125MB/s  ]
# Downloading bytes:  73% 6.82G/9.32G [00:36<00:23, 105MB/s,  108MB/s  ]
# Downloading bytes:  73% 6.85G/9.32G [00:37<00:37, 66.0MB/s, 79.8MB/s  ]
# Downloading bytes:  80% 7.41G/9.32G [00:40<00:11, 167MB/s,  178MB/s  ]
# Reconstructing (incomplete total...):  64% 5.99G/9.32G [00:43<00:30, 109MB/s,  194MB/s  ]
# Downloading bytes:  86% 8.03G/9.32G [00:46<00:04, 269MB/s,  258MB/s  ]
# Reconstructing (incomplete total...):  72% 6.68G/9.32G [00:49<00:26, 100MB/s,  175MB/s  ]
# Downloading bytes:  86% 8.05G/9.32G [00:59<00:04, 269MB/s,  269MB/s  ]
# Reconstructing (incomplete total...):  80% 7.50G/9.32G [01:00<00:21, 84.9MB/s, 85.9MB/s  ]
# Reconstructing (incomplete total...):  84% 7.80G/9.32G [01:03<00:17, 84.9MB/s, 84.9MB/s  ]
# Reconstructing (incomplete total...):  87% 8.15G/9.32G [01:04<00:10, 110MB/s, 84.9MB/s  ]
# Reconstructing (incomplete total...):  89% 8.28G/9.32G [01:05<00:08, 125MB/s,  110MB/s  ]
# Reconstructing (incomplete total...):  89% 8.34G/9.32G [01:05<00:07, 131MB/s,  125MB/s  ]
#
# Fetching 2 files:  50% 1/2 [01:05<01:05, 65.44s/it]
# Reconstructing (incomplete total...):  92% 8.55G/9.32G [01:06<00:04, 155MB/s,  131MB/s  ]
# Reconstructing (incomplete total...):  99% 9.26G/9.32G [01:09<00:00, 198MB/s,  155MB/s  ]
#
# Fetching 2 files: 100% 2/2 [01:09<00:00, 34.58s/it]
# Download complete: 100% 8.05G/8.05G [01:09<00:00, 269MB/s,  269MB/s  ]
# Download complete: 100% 8.05G/8.05G [01:09<00:00, 116MB/s,  269MB/s  ]
# Reconstruction complete: 100% 9.32G/9.32G [01:09<00:00, 134MB/s,  198MB/s  ]
# Loading weights: 100% 426/426 [00:34<00:00, 12.47it/s]
#   [(a) base + naive prompt/target] batch 1/2     15s elapsed  ~   15s left
#   [(a) base + naive prompt/target] batch 2/2     27s elapsed  ~    0s left
#   [(a) base + naive prompt/target] done: 8 prompts in 27s
#   [(a) base + naive prompt/regression] batch 1/2      5s elapsed  ~    5s left
#   [(a) base + naive prompt/regression] batch 2/2     13s elapsed  ~    0s left
#   [(a) base + naive prompt/regression] done: 8 prompts in 13s
# (a) base + naive prompt      target=0.000  regression=0.750  format=0.000  3370ms
#   [(b) base + optimized prompt/target] batch 1/2      4s elapsed  ~    4s left
#   [(b) base + optimized prompt/target] batch 2/2      8s elapsed  ~    0s left
#   [(b) base + optimized prompt/target] done: 8 prompts in 8s
#   [(b) base + optimized prompt/regression] batch 1/2      5s elapsed  ~    5s left
#   [(b) base + optimized prompt/regression] batch 2/2     12s elapsed  ~    0s left
#   [(b) base + optimized prompt/regression] done: 8 prompts in 12s
# (b) base + optimized prompt  target=0.688  regression=0.750  format=1.000  1043ms
# {
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "baseline_a": {
#     "target": 0.0,
#     "regression": 0.75,
#     "format": 0.0,
#     "latency_ms": 3369.550733625005,
#     "n": 8,
#     "extra": {}
#   },
#   "baseline_b": {
#     "target": 0.6875,
#     "regression": 0.75,
#     "format": 1.0,
#     "latency_ms": 1043.2895786250072,
#     "n": 8,
#     "extra": {}
#   },
#   "optimized_prompt_sha": "719e74d3b6232053",
#   "n_target": 8,
#   "n_regression": 8,
#   "eval_limit": 8,
#   "smoke_mode": true
# }
#
# -- NB2 ok in 180s
#
# ========================================================================
# NB3 — train the correct configuration
# ========================================================================
# T4 · unsloth/Qwen3.5-4B · all-linear · r=16 · LR 10x · 16-bit
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1070.11it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:32<00:00, 13.12it/s]
# {
#   "num_hidden_layers": 32,
#   "full_attention_interval": 4,
#   "linear_num_key_heads": 16,
#   "layer_types": {
#     "linear_attention": 24,
#     "full_attention": 8
#   }
# }
# placement=text-linear  modules=['down_proj', 'gate_proj', 'in_proj_a', 'in_proj_b', 'in_proj_qkv', 'in_proj_z', 'k_proj', 'o_proj', 'out_proj', 'q_proj', 'up_proj', 'v_proj']
# trainable LoRA params ≈ 32.46 M
#     {'placement': 'text-linear', 'modules': 12, 'r': 16, 'trainable': 32464896}
#     {'placement': 'attn-only(q,v)', 'modules': 2, 'r': 16, 'trainable': 1835008}
#     {'placement': 'attn-only(q,v) matched', 'modules': 2, 'r': 283, 'trainable': 32456704}
# Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
# mask_mode = assistant-only   supervised 9014/20951 tokens (43.0%)
# epochs=2.0  ->  30 optimizer steps  (NB4 runs its contrasts at exactly this many)
# {
#   "output_dir": "/content/Day21-Track3-Finetuning-Lab/adapters/correct",
#   "max_length": "1024",
#   "per_device_train_batch_size": "1",
#   "gradient_accumulation_steps": "16",
#   "learning_rate": "0.0001",
#   "lr_scheduler_type": "cosine",
#   "num_train_epochs": "2.0",
#   "logging_steps": "5",
#   "save_strategy": "no",
#   "report_to": "none",
#   "seed": "42",
#   "packing": "False",
#   "loss_type": "chunked_nll",
#   "gradient_checkpointing": "True",
#   "warmup_steps": "3",
#   "bf16": "False",
#   "fp16": "True",
#   "padding_free": "False"
# }
# Truncating train dataset: 100% 225/225 [00:00<00:00, 4692.83 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 27123.02 examples/s]
# precision fix: {'precision': 'fp16', 'recast': 0, 'trainable_tensors': 496}
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '1.381', 'grad_norm': '2.538', 'learning_rate': '8.83e-05', 'entropy': '1.03', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.7694', 'epoch': '0.7111'}
# {'loss': '0.1407', 'grad_norm': '0.59', 'learning_rate': '6.434e-05', 'entropy': '0.27', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9583', 'epoch': '1'}
# {'loss': '0.02834', 'grad_norm': '0.8193', 'learning_rate': '3.566e-05', 'entropy': '0.04209', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9882', 'epoch': '1.356'}
# {'loss': '0.01764', 'grad_norm': '0.2352', 'learning_rate': '1.17e-05', 'entropy': '0.02114', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9934', 'epoch': '1.711'}
# {'loss': '0.02447', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.01547', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.9965', 'epoch': '2'}
# {'train_runtime': '979.1', 'train_samples_per_second': '0.46', 'train_steps_per_second': '0.031', 'train_loss': '0.6259', 'epoch': '2'}
# 100% 30/30 [16:19<00:00, 32.64s/it]
# train 980s  final loss 0.6259
# saved -> /content/Day21-Track3-Finetuning-Lab/adapters/correct
# {
#   "run": "correct",
#   "label": "all-linear · r=16 · LR 10x · 16-bit",
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "precision": "fp16",
#   "placement": "text-linear",
#   "n_target_modules": 12,
#   "r": 16,
#   "lora_alpha": 32,
#   "learning_rate": 0.0001,
#   "load_in_4bit": false,
#   "trainable_params": 32464896,
#   "train_seconds": 979.6,
#   "peak_vram_gb": 12.01,
#   "final_loss": 0.6259,
#   "mask_mode": "assistant-only",
#   "max_steps": 30
# }
#
# -- NB3 ok in 1040s
#
# ========================================================================
# NB4 — three misconfiguration contrasts
# ========================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 985.74it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:32<00:00, 13.03it/s]
# | placement | modules | r | trainable |
# |---|---|---|---|
# | text-linear | 12 | 16 | 32464896 |
# | attn-only(q,v) | 2 | 16 | 1835008 |
# | attn-only(q,v) matched | 2 | 283 | 32456704 |
# ======================================================================
# RUN attn_only: q,v only · r=matched · LR 10x · 16-bit
#      Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1239.27it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:32<00:00, 13.09it/s]
#   train_ds: Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
#   matched rank for attn_only: r=283 (alpha=566)
# Truncating train dataset: 100% 225/225 [00:00<00:00, 6730.56 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 39121.10 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': '5.89', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '0.8228', 'grad_norm': '1.849', 'learning_rate': '8.83e-05', 'entropy': '0.9384', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.841', 'epoch': '0.7111'}
# {'loss': '0.1459', 'grad_norm': '1.249', 'learning_rate': '6.434e-05', 'entropy': '0.2832', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9587', 'epoch': '1'}
# {'loss': '0.0395', 'grad_norm': '0.9266', 'learning_rate': '3.566e-05', 'entropy': '0.06411', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9879', 'epoch': '1.356'}
# {'loss': '0.0206', 'grad_norm': '0.2204', 'learning_rate': '1.17e-05', 'entropy': '0.03169', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9912', 'epoch': '1.711'}
# {'loss': '0.02465', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.02181', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.995', 'epoch': '2'}
# {'train_runtime': '799.9', 'train_samples_per_second': '0.6', 'train_steps_per_second': '0.038', 'train_loss': '0.5361', 'epoch': '2'}
# 100% 30/30 [13:19<00:00, 26.66s/it]
# ======================================================================
# RUN wrong_lr: all-linear · r=16 · LR 1x (full-FT scale) · 16-bit
#      Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 950.66it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:32<00:00, 13.08it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 10071.16 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 44613.93 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
#   7% 2/30 [01:05<15:15, 32.71s/it]

# %%
# @title 4. Gatekeeper + results
# !python scripts/verify.py
print("\n================ results/ ================")
# !ls -la results/
# !echo && echo "---- runs.csv ----" && cat results/runs.csv 2>/dev/null
# !echo && echo "---- verdict.json ----" && cat results/verdict.json 2>/dev/null
