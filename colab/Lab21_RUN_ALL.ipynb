# %% [markdown]
# # Lab 21 — Fine-tuning LLMs · RUN ALL (T4)
#
# Chay tu tren xuong. Runtime > Change runtime type > **T4 GPU** truoc khi bat dau.
#
# | O | Lam gi | Thoi gian |
# |---|---|---|
# | 1 | clone + install | ~1 phut |
# | 2 | smoke: import + unit test | ~30 giay |
# | 3 | **core pipeline NB1 -> NB5** | ~80 phut |
# | 4 | gatekeeper + in ket qua | ~10 giay |

# %%
# @title 1. Setup — clone + install (chạy ô này trước)
import os, subprocess, sys

REPO = "https://github.com/hieutrungdao/Day21-Track3-Finetuning-Lab.git"
if not os.path.exists("Day21-Track3-Finetuning-Lab"):
    subprocess.run(["git", "clone", "-q", REPO], check=True)
os.chdir("/content/Day21-Track3-Finetuning-Lab")
subprocess.run(["git", "pull", "-q"], check=False)
sys.path.insert(0, "src")

# Install from requirements.txt, NOT a copied list. The copied list is how the
# torchao>=0.16 pin reached requirements.txt and this bootstrap on different days --
# and a bootstrap missing a pin does not fail here, it fails 10 minutes later inside
# get_peft_model(). One source of truth. torch is preinstalled on Colab and
# requirements.txt pins it compatibly, so that line is a no-op.
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"],
               check=True)

import torch
print("commit :", subprocess.run(["git","rev-parse","--short","HEAD"],
                                 capture_output=True, text=True).stdout.strip())
print("GPU    :", torch.cuda.get_device_name(0) if torch.cuda.is_available()
      else "NONE — Runtime > Change runtime type > T4 GPU")
if torch.cuda.is_available():
    print("VRAM   : %.1f GB" % (torch.cuda.get_device_properties(0).total_memory/1024**3))
# Out:
# commit : 4f619a4
# GPU    : Tesla T4
# VRAM   : 14.6 GB

# %%
# @title 2. Smoke — imports, seed data, unit tests (no GPU needed)
# !python scripts/verify.py --smoke
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 2.13s
#
# 6 passed · 0 warnings · 1 failures
#
# Not ready to submit — fix the FAILs above.

# %%
# @title 3. Core pipeline — NB1 → NB5
# EVAL_LIMIT truncates both eval sets: "" = full run (submittable),
# 8 = ~fast smoke pass. STAGES lets you resume after a failure.
import os
import sys # Thêm dòng này để truy cập sys.path
COMPUTE_TIER = "T4"        # @param ["CPU","LAPTOP","T4","BIGGPU"]
EVAL_LIMIT   = "8"         # @param ["", "4", "8", "16", "25"]
STAGES       = "nb1 nb2 nb3 nb4 nb5"   # @param {type:"string"}

os.environ["COMPUTE_TIER"] = COMPUTE_TIER
if EVAL_LIMIT:
    os.environ["EVAL_LIMIT"] = EVAL_LIMIT
else:
    os.environ.pop("EVAL_LIMIT", None)

# Đảm bảo thư mục 'src' nằm trong sys.path để tìm thấy các mô-đun cục bộ như 'labkit'.
# Điều này hữu ích nếu môi trường bị reset hoặc ô thiết lập trước đó chưa hoàn chỉnh.
if os.path.isdir("src") and os.path.abspath("src") not in sys.path:
    sys.path.insert(0, os.path.abspath("src"))

from labkit import device
print(device.banner(), "\n")

# !python scripts/colab_run.py {STAGES}
# Out:
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
#
# tier=T4  mask=assistant-only  eval_limit=8
#
# ========================================================================
# NB1 — data, chat template & loss mask
# ========================================================================
# tier=T4  model=unsloth/Qwen3.5-4B  max_length=1024
# 250 mẫu huấn luyện
# {
#   "instruction": "Phân loại ticket chăm sóc khách hàng sau thành JSON với đúng 4 khóa: intent, urgency, product, sentiment. Chỉ trả về JSON, không giải thích.\n\nintent thuộc: doi_tra | van_chuyen | hoan_tien | san_pham_loi | hoi_thong_tin\nurgency thuộc: cao | trung_binh | thap\nsentiment thuộc: tieu_cuc | trung_tinh | tich_cuc\nproduct: tên sản phẩm xuất hiện trong ticket.",
#   "input": "Alo sh
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 2.76k/2.76k [00:00<00:00, 11.7MB/s]
# tokenizer_config.json: 100% 15.7k/15.7k [00:00<00:00, 49.2MB/s]
# vocab.json: 100% 5.23M/5.23M [00:00<00:00, 86.9MB/s]
# merges.txt: 100% 3.35M/3.35M [00:00<00:00, 94.3MB/s]
#
# tokenizer.json: downloading bytes:  13% 2.67M/20.0M [00:01<00:08, 1.93MB/s]
# tokenizer.json: downloading bytes: 100% 6.23M/6.23M [00:01<00:00, 4.32MB/s,  605kB/s  ]
# tokenizer.json: reconstructing file: 100% 20.0M/20.0M [00:01<00:00, 13.9MB/s, 1.94MB/s  ]
# added_tokens.json: 100% 904/904 [00:00<00:00, 5.74MB/s]
# special_tokens_map.json: 100% 876/876 [00:00<00:00, 4.91MB/s]
# chat_template.jinja: 100% 7.99k/7.99k [00:00<00:00, 18.0MB/s]
# eos_token: <|im_end|>
# VERDICT: reasoning preserved — safe to train on traces
#
# --- chuỗi đã render ---
# <|im_start|>user
# 2+2?<|im_end|>
# <|im_start|>assistant
# <think>
# buoc 1: kiem tra. buoc 2: tra loi.
# </think>
#
# 4<|im_end|>
#
# ======================================================================
# mode = assistant-only   supervised 39/94 (41%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# ======================================================================
# mode = everything   supervised 94/94 (100%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# <|im_start|>system
# Phân loại ticket sau.<|im_end|>
# <|im_start|>user
# Alo shop, mình đặt balo laptop mã đơn VN411453. Cho tôi trả lại. Đã 3 ngày rồi. Cho tôi hỏi.<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# {
#   "mask_mode": "assistant-only",
#   "n_supervised": 39,
#   "n_total": 94,
#   "supervised_fraction": 0.4149,
#   "answer_is_supervised": true,
#   "question_is_masked": true
# }
# {
#   "n": 250,
#   "mean": 93.1,
#   "p50": 93,
#   "p95": 98,
#   "p99": 100,
#   "max": 101,
#   "suggested_max_length": 256
# }
#
# ⚠ p95 gợi ý max_length=256 nhưng tier đang đặt 1024. Ghi lại lựa chọn của bạn trong REPORT.md.
# train=225  val=25  -> /content/Day21-Track3-Finetuning-Lab/data/split
#
# -- NB1 ok in 22s
#
# ========================================================================
# NB2 — freeze eval + three baselines
# ========================================================================
# ⚠ EVAL_LIMIT=8 — SMOKE MODE, not a submittable run
# target=8  regression=8  tier=T4
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# model.safetensors.index.json: 100% 76.2k/76.2k [00:00<00:00, 168MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/5.33G [00:00<?, ?B/s]
# Downloading bytes:   0% 339k/9.32G [00:01<10:54:07, 237kB/s]
# Downloading bytes:   2% 148M/9.32G [00:01<00:55, 165MB/s,  130MB/s  ]
# Downloading bytes:   3% 279M/9.32G [00:02<00:38, 238MB/s,  217MB/s  ]
# Downloading bytes:   4% 342M/9.32G [00:02<00:41, 216MB/s,  250MB/s  ]
# Downloading bytes:   5% 447M/9.32G [00:03<00:36, 241MB/s,  252MB/s  ]
# Downloading bytes:  12% 1.13G/9.32G [00:05<00:34, 238MB/s,  280MB/s  ]
# Downloading bytes:  17% 1.60G/9.32G [00:08<00:45, 171MB/s,  141MB/s  ]
# Downloading bytes:  31% 2.90G/9.32G [00:13<00:27, 231MB/s,  213MB/s  ]
# Downloading bytes:  31% 2.92G/9.32G [00:19<06:33, 16.2MB/s,  231MB/s  ]
# Downloading bytes:  39% 3.62G/9.32G [00:22<00:27, 210MB/s,  244MB/s  ]
# Downloading bytes:  40% 3.74G/9.32G [00:27<01:44, 53.3MB/s, 45.5MB/s  ]
# Downloading bytes:  42% 3.91G/9.32G [00:37<02:03, 43.9MB/s, 32.5MB/s  ]
# Downloading bytes:  43% 4.04G/9.32G [00:41<01:54, 46.3MB/s, 38.3MB/s  ]
# Downloading bytes:  47% 4.42G/9.32G [00:48<00:23, 211MB/s,  244MB/s  ]
# Downloading bytes:  49% 4.53G/9.32G [01:09<02:35, 30.7MB/s, 30.7MB/s  ]
# Reconstructing (incomplete total...):  24% 2.28G/9.32G [01:09<03:03, 38.4MB/s, 38.4MB/s  ]
# Reconstructing (incomplete total...):  27% 2.54G/9.32G [01:10<04:17, 26.3MB/s, 38.4MB/s  ]
# Downloading bytes:  55% 5.09G/9.32G [01:12<00:13, 318MB/s,  307MB/s  ]
# Downloading bytes:  56% 5.19G/9.32G [01:16<01:23, 49.1MB/s, 39.9MB/s  ]
# Downloading bytes:  58% 5.44G/9.32G [01:23<00:33, 115MB/s, 88.3MB/s  ]
# Downloading bytes:  60% 5.58G/9.32G [01:34<01:36, 38.6MB/s, 31.1MB/s  ]
# Downloading bytes:  64% 6.00G/9.32G [01:36<00:16, 205MB/s,  204MB/s  ]
# Downloading bytes:  67% 6.21G/9.32G [01:49<00:25, 123MB/s,  123MB/s  ]
# Reconstructing (incomplete total...):  45% 4.20G/9.32G [01:49<01:35, 53.5MB/s, 53.5MB/s  ]
# Downloading bytes:  69% 6.44G/9.32G [01:58<00:55, 51.5MB/s, 35.8MB/s  ]
# Reconstructing (incomplete total...):  53% 4.91G/9.32G [02:07<02:07, 34.7MB/s, 29.4MB/s  ]
# Downloading bytes:  75% 7.01G/9.32G [02:09<00:11, 200MB/s,  172MB/s  ]
# Reconstructing (incomplete total...):  55% 5.15G/9.32G [02:19<01:38, 42.2MB/s, 42.2MB/s  ]
# Downloading bytes:  76% 7.05G/9.32G [02:24<03:42, 10.2MB/s, 9.66MB/s  ]
# Downloading bytes:  81% 7.51G/9.32G [02:26<00:07, 258MB/s,  233MB/s  ]
# Downloading bytes:  82% 7.63G/9.32G [02:36<01:05, 25.8MB/s, 20.2MB/s  ]
# Downloading bytes:  84% 7.83G/9.32G [02:43<00:23, 62.7MB/s, 46.0MB/s  ]
# Downloading bytes:  86% 8.03G/9.32G [02:50<00:14, 87.7MB/s, 66.4MB/s  ]
# Downloading bytes:  86% 8.05G/9.32G [03:09<00:14, 87.7MB/s, 87.7MB/s  ]
# Reconstructing (incomplete total...):  70% 6.52G/9.32G [03:09<01:24, 33.0MB/s, 33.0MB/s  ]
# Reconstructing (incomplete total...):  73% 6.78G/9.32G [03:17<02:04, 20.4MB/s, 33.0MB/s  ]
# Reconstructing (incomplete total...):  73% 6.78G/9.32G [03:29<02:04, 20.4MB/s, 20.4MB/s  ]
# Reconstructing (incomplete total...):  77% 7.15G/9.32G [03:39<01:56, 18.6MB/s, 20.4MB/s  ]
# Reconstructing (incomplete total...):  84% 7.86G/9.32G [03:40<00:38, 38.0MB/s, 18.6MB/s  ]
# Reconstructing (incomplete total...):  85% 7.92G/9.32G [03:45<00:41, 33.5MB/s, 38.0MB/s  ]
#
# Fetching 2 files:  50% 1/2 [03:47<03:47, 227.18s/it]
# Reconstructing (incomplete total...):  90% 8.34G/9.32G [03:56<00:27, 36.1MB/s, 33.5MB/s  ]
# Reconstructing (incomplete total...):  91% 8.51G/9.32G [04:02<00:23, 34.2MB/s, 36.1MB/s  ]
# Reconstructing (incomplete total...):  94% 8.78G/9.32G [04:06<00:13, 39.4MB/s, 34.2MB/s  ]
# Reconstructing (incomplete total...):  97% 9.06G/9.32G [04:10<00:05, 44.5MB/s, 39.4MB/s  ]
# Reconstructing (incomplete total...):  99% 9.23G/9.32G [04:16<00:02, 40.2MB/s, 44.5MB/s  ]
# Reconstructing (incomplete total...): 100% 9.32G/9.32G [04:17<00:00, 44.4MB/s, 40.2MB/s  ]
#
# Fetching 2 files: 100% 2/2 [04:20<00:00, 130.12s/it]
# Download complete: 100% 8.05G/8.05G [04:20<00:00, 87.7MB/s, 87.7MB/s  ]
# Download complete: 100% 8.05G/8.05G [04:20<00:00, 30.9MB/s, 87.7MB/s  ]
# Reconstruction complete: 100% 9.32G/9.32G [04:20<00:00, 35.8MB/s, 44.4MB/s  ]
# Loading weights: 100% 426/426 [00:30<00:00, 14.19it/s]
#   [(a) base + naive prompt/target] batch 1/2     14s elapsed  ~   14s left
#   [(a) base + naive prompt/target] batch 2/2     27s elapsed  ~    0s left
#   [(a) base + naive prompt/target] done: 8 prompts in 27s
#   [(a) base + naive prompt/regression] batch 1/2      5s elapsed  ~    5s left
#   [(a) base + naive prompt/regression] batch 2/2     13s elapsed  ~    0s left
#   [(a) base + naive prompt/regression] done: 8 prompts in 13s
# (a) base + naive prompt      target=0.000  regression=0.750  format=0.000  3336ms
#   [(b) base + optimized prompt/target] batch 1/2      4s elapsed  ~    4s left
#   [(b) base + optimized prompt/target] batch 2/2      8s elapsed  ~    0s left
#   [(b) base + optimized prompt/target] done: 8 prompts in 8s
#   [(b) base + optimized prompt/regression] batch 1/2      5s elapsed  ~    5s left
#   [(b) base + optimized prompt/regression] batch 2/2     12s elapsed  ~    0s left
#   [(b) base + optimized prompt/regression] done: 8 prompts in 12s
# (b) base + optimized prompt  target=0.688  regression=0.750  format=1.000  954ms
# {
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "baseline_a": {
#     "target": 0.0,
#     "regression": 0.75,
#     "format": 0.0,
#     "latency_ms": 3335.8572362500067,
#     "n": 8,
#     "extra": {}
#   },
#   "baseline_b": {
#     "target": 0.6875,
#     "regression": 0.75,
#     "format": 1.0,
#     "latency_ms": 953.698966250002,
#     "n": 8,
#     "extra": {}
#   },
#   "optimized_prompt_sha": "719e74d3b6232053",
#   "n_target": 8,
#   "n_regression": 8,
#   "eval_limit": 8,
#   "smoke_mode": true
# }
#
# -- NB2 ok in 367s
#
# ========================================================================
# NB3 — train the correct configuration
# ========================================================================
# T4 · unsloth/Qwen3.5-4B · all-linear · r=16 · LR 10x · 16-bit
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 972.59it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.49it/s]
# {
#   "num_hidden_layers": 32,
#   "full_attention_interval": 4,
#   "linear_num_key_heads": 16,
#   "layer_types": {
#     "linear_attention": 24,
#     "full_attention": 8
#   }
# }
# placement=text-linear  modules=['down_proj', 'gate_proj', 'in_proj_a', 'in_proj_b', 'in_proj_qkv', 'in_proj_z', 'k_proj', 'o_proj', 'out_proj', 'q_proj', 'up_proj', 'v_proj']
# trainable LoRA params ≈ 32.46 M
#     {'placement': 'text-linear', 'modules': 12, 'r': 16, 'trainable': 32464896}
#     {'placement': 'attn-only(q,v)', 'modules': 2, 'r': 16, 'trainable': 1835008}
#     {'placement': 'attn-only(q,v) matched', 'modules': 2, 'r': 283, 'trainable': 32456704}
# Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
# mask_mode = assistant-only   supervised 9014/20951 tokens (43.0%)
# epochs=2.0  ->  30 optimizer steps  (NB4 runs its contrasts at exactly this many)
# {
#   "output_dir": "/content/Day21-Track3-Finetuning-Lab/adapters/correct",
#   "max_length": "1024",
#   "per_device_train_batch_size": "1",
#   "gradient_accumulation_steps": "16",
#   "learning_rate": "0.0001",
#   "lr_scheduler_type": "cosine",
#   "num_train_epochs": "2.0",
#   "logging_steps": "5",
#   "save_strategy": "no",
#   "report_to": "none",
#   "seed": "42",
#   "packing": "False",
#   "loss_type": "chunked_nll",
#   "gradient_checkpointing": "True",
#   "warmup_steps": "3",
#   "bf16": "False",
#   "fp16": "True",
#   "padding_free": "False"
# }
# Truncating train dataset: 100% 225/225 [00:00<00:00, 5464.37 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 27142.52 examples/s]
# precision fix: {'precision': 'fp16', 'recast': 0, 'trainable_tensors': 496}
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '1.389', 'grad_norm': '2.506', 'learning_rate': '8.83e-05', 'entropy': '1.035', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.7684', 'epoch': '0.7111'}
# {'loss': '0.1454', 'grad_norm': '0.8602', 'learning_rate': '6.434e-05', 'entropy': '0.2747', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9584', 'epoch': '1'}
# {'loss': '0.03217', 'grad_norm': '1.046', 'learning_rate': '3.566e-05', 'entropy': '0.0405', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9886', 'epoch': '1.356'}
# {'loss': '0.02154', 'grad_norm': '0.2482', 'learning_rate': '1.17e-05', 'entropy': '0.02156', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9918', 'epoch': '1.711'}
# {'loss': '0.02223', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.01807', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.9957', 'epoch': '2'}
# {'train_runtime': '962', 'train_samples_per_second': '0.468', 'train_steps_per_second': '0.031', 'train_loss': '0.629', 'epoch': '2'}
# 100% 30/30 [16:01<00:00, 32.07s/it]
# train 963s  final loss 0.6290
# saved -> /content/Day21-Track3-Finetuning-Lab/adapters/correct
# {
#   "run": "correct",
#   "label": "all-linear · r=16 · LR 10x · 16-bit",
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "precision": "fp16",
#   "placement": "text-linear",
#   "n_target_modules": 12,
#   "r": 16,
#   "lora_alpha": 32,
#   "learning_rate": 0.0001,
#   "load_in_4bit": false,
#   "trainable_params": 32464896,
#   "train_seconds": 962.5,
#   "peak_vram_gb": 12.01,
#   "final_loss": 0.629,
#   "mask_mode": "assistant-only",
#   "max_steps": 30
# }
#
# -- NB3 ok in 1031s
#
# ========================================================================
# NB4 — three misconfiguration contrasts
# ========================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1050.68it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.58it/s]
# | placement | modules | r | trainable |
# |---|---|---|---|
# | text-linear | 12 | 16 | 32464896 |
# | attn-only(q,v) | 2 | 16 | 1835008 |
# | attn-only(q,v) matched | 2 | 283 | 32456704 |
# ======================================================================
# RUN attn_only: q,v only · r=matched · LR 10x · 16-bit
#      Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1021.38it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.62it/s]
#   train_ds: Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
#   matched rank for attn_only: r=283 (alpha=566)
# Truncating train dataset: 100% 225/225 [00:00<00:00, 6648.90 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 43735.21 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': '5.797', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '0.8257', 'grad_norm': '1.818', 'learning_rate': '8.83e-05', 'entropy': '0.9392', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.8409', 'epoch': '0.7111'}
# {'loss': '0.1485', 'grad_norm': '1.362', 'learning_rate': '6.434e-05', 'entropy': '0.2893', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9584', 'epoch': '1'}
# {'loss': '0.0401', 'grad_norm': '0.9267', 'learning_rate': '3.566e-05', 'entropy': '0.06458', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.986', 'epoch': '1.356'}
# {'loss': '0.0219', 'grad_norm': '0.2245', 'learning_rate': '1.17e-05', 'entropy': '0.03155', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9909', 'epoch': '1.711'}
# {'loss': '0.02576', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.02288', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.9946', 'epoch': '2'}
# {'train_runtime': '786.6', 'train_samples_per_second': '0.61', 'train_steps_per_second': '0.038', 'train_loss': '0.5376', 'epoch': '2'}
# 100% 30/30 [13:06<00:00, 26.22s/it]
# ======================================================================
# RUN wrong_lr: all-linear · r=16 · LR 1x (full-FT scale) · 16-bit
#      Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1060.77it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.60it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 10339.51 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 45987.93 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-06', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '2.066', 'grad_norm': '5.105', 'learning_rate': '8.83e-06', 'entropy': '1.199', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.6793', 'epoch': '0.7111'}
# {'loss': '1.606', 'grad_norm': 'nan', 'learning_rate': '6.434e-06', 'entropy': '1.178', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.7176', 'epoch': '1'}
# {'loss': '1.326', 'grad_norm': '4.63', 'learning_rate': '3.566e-06', 'entropy': '1.103', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.7564', 'epoch': '1.356'}
# {'loss': '1.141', 'grad_norm': '4.213', 'learning_rate': '1.17e-06', 'entropy': '1.077', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.7979', 'epoch': '1.711'}
# {'loss': '1.119', 'grad_norm': 'nan', 'learning_rate': '3.381e-08', 'entropy': '1.069', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.7905', 'epoch': '2'}
# {'train_runtime': '922', 'train_samples_per_second': '0.521', 'train_steps_per_second': '0.033', 'train_loss': '1.57', 'epoch': '2'}
# 100% 30/30 [15:21<00:00, 30.73s/it]
# ======================================================================
# RUN qlora: all-linear · r=16 · LR 10x · 4-bit QLoRA
#      The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 790.71it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.46it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 10358.35 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 47392.08 examples/s]
#   precision fix: recast 496/496 trainable tensors bf16 -> fp32 for the fp16 GradScaler
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.155', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.34', 'num_tokens': '7479', 'mean_token_accuracy': '0.656', 'epoch': '0.3556'}
# {'loss': '1.731', 'grad_norm': '3.368', 'learning_rate': '8.83e-05', 'entropy': '1.287', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.7214', 'epoch': '0.7111'}
# {'loss': '0.2408', 'grad_norm': '1.019', 'learning_rate': '6.434e-05', 'entropy': '0.3825', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9382', 'epoch': '1'}
# {'loss': '0.0513', 'grad_norm': '1.023', 'learning_rate': '3.566e-05', 'entropy': '0.07534', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9829', 'epoch': '1.356'}
# {'loss': '0.03019', 'grad_norm': '0.3238', 'learning_rate': '1.17e-05', 'entropy': '0.0355', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9884', 'epoch': '1.711'}
# {'loss': '0.02674', 'grad_norm': '3.368', 'learning_rate': '3.381e-07', 'entropy': '0.03056', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.992', 'epoch': '2'}
# {'train_runtime': '982', 'train_samples_per_second': '0.489', 'train_steps_per_second': '0.031', 'train_loss': '0.7058', 'epoch': '2'}
# 100% 30/30 [16:21<00:00, 32.73s/it]
# | run | label | r | trainable_params | learning_rate | final_loss | train_seconds | peak_vram_gb |
# |---|---|---|---|---|---|---|---|
# | correct | all-linear · r=16 · LR 10x · 16-bit | 16 | 32464896 | 0.0001 | 0.629 | 962.5 | 12.01 |
# | attn_only | q,v only · r=matched · LR 10x · 16-bit | 283 | 32456704 | 0.0001 | 0.5376 | 786.9 | 12.02 |
# | wrong_lr | all-linear · r=16 · LR 1x (full-FT scale) · 16-bit | 16 | 32464896 | 1e-05 | 1.5704 | 922.4 | 12.01 |
# | qlora | all-linear · r=16 · LR 10x · 4-bit QLoRA | 16 | 32464896 | 0.0001 | 0.7058 | 982.4 | 7.09 |
#
# -- NB4 ok in 2909s
#
# ========================================================================
# NB5 — four-group eval + verdict
# ========================================================================
# baseline (b) target = 0.688 — đây là mốc phải vượt
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 970.57it/s]
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Download complete: :           |  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.55it/s]
#   [ft/target] batch 1/2      6s elapsed  ~    6s left
#   [ft/target] batch 2/2     12s elapsed  ~    0s left
#   [ft/target] done: 8 prompts in 12s
#   [ft/regression] batch 1/2      9s elapsed  ~    9s left
#   [ft/regression] batch 2/2     21s elapsed  ~    0s left
#   [ft/regression] done: 8 prompts in 21s
# fine-tune: {'target': 0.96875, 'regression': 0.7916666666666666, 'format': 1.0, 'latency_ms': 1528.7498993750432, 'n': 8, 'extra': {'valid_trace_rate': 0.0}}
# | run | target | regression | format | latency_ms | n |
# |---|---|---|---|---|---|
# | (a) base + naive prompt | 0.0 | 0.75 | 0.0 | 3335.9 | 8 |
# | (b) base + optimized prompt | 0.6875 | 0.75 | 1.0 | 953.7 | 8 |
# | (c) LoRA fine-tune | 0.9688 | 0.7917 | 1.0 | 1528.7 | 8 |
# PASSED
#  - beat the optimized-prompt baseline by +0.281 with +0.042 general-capability change.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1010.92it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.42it/s]
#   [attn_only/target] batch 1/2      3s elapsed  ~    3s left

# %%
# @title 4. Gatekeeper + results
# !python scripts/verify.py
print("\n================ results/ ================")
# !ls -la results/
# !echo && echo "---- runs.csv ----" && cat results/runs.csv 2>/dev/null
# !echo && echo "---- verdict.json ----" && cat results/verdict.json 2>/dev/null
